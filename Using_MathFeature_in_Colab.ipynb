# %%
# !git clone https://github.com/Bonidia/MathFeature.git MathFeature
# Out:
# Cloning into 'MathFeature'...
# remote: Enumerating objects: 857, done.
# remote: Counting objects: 100% (276/276), done.
# remote: Compressing objects: 100% (158/158), done.
# remote: Total 857 (delta 139), reused 245 (delta 117), pack-reused 581 (from 1)
# Receiving objects: 100% (857/857), 111.91 MiB | 19.11 MiB/s, done.
# Resolving deltas: 100% (490/490), done.
# Updating files: 100% (152/152), done.

# %%
# !pwd
# Out:
# /content

# %%
# !ls -l
# Out:
# total 8
# drwxr-xr-x 12 root root 4096 Nov  3 19:51 MathFeature
# drwxr-xr-x  1 root root 4096 Oct 31 17:50 sample_data

# %%
# %cd /content/MathFeature
# Out:
# /content/MathFeature

# %%
# !ls -l
# Out:
# total 60
# drwxr-xr-x 11 root root  4096 Nov  3 19:51 'Case Studies'
# drwxr-xr-x 11 root root  4096 Nov  3 19:51 'Codes - Case Studies Experiments'
# drwxr-xr-x  2 root root  4096 Nov  3 19:51  documentation
# drwxr-xr-x  2 root root  4096 Nov  3 19:51  examples
# drwxr-xr-x  2 root root  4096 Nov  3 19:51  files
# drwxr-xr-x  4 root root  4096 Nov  3 19:51  GUI
# drwxr-xr-x  2 root root  4096 Nov  3 19:51  img
# -rw-r--r--  1 root root  2077 Nov  3 19:51  mathfeature-gui.yml
# -rw-r--r--  1 root root   944 Nov  3 19:51  mathfeature-terminal.yml
# drwxr-xr-x  2 root root  4096 Nov  3 19:51  methods
# drwxr-xr-x  2 root root  4096 Nov  3 19:51  preprocessing
# -rw-r--r--  1 root root 10590 Nov  3 19:51  README.md
# -rw-r--r--  1 root root   158 Nov  3 19:51  requirements.txt

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 50.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 80.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 62.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 84.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 27.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.3
#     Uninstalling scipy-1.16.3:
#       Successfully uninstalled scipy-1.16.3
#   Attempting uninstall: pandas
# ...

# %%
# !apt-get -y install python3-igraph
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   python3-texttable
# The following NEW packages will be installed:
#   python3-igraph python3-texttable
# 0 upgraded, 2 newly installed, 0 to remove and 41 not upgraded.
# Need to get 1,449 kB of archives.
# After this operation, 4,328 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-texttable all 1.6.4-1 [11.4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-igraph amd64 0.9.9-1build1 [1,438 kB]
# Fetched 1,449 kB in 1s (1,437 kB/s)
# Selecting previously unselected package python3-texttable.
# (Reading database ... 125080 files and directories currently installed.)
# Preparing to unpack .../python3-texttable_1.6.4-1_all.deb ...
# Unpacking python3-texttable (1.6.4-1) ...
# Selecting previously unselected package python3-igraph.
# ...

# %%
# !python methods/ExtractionTechniques.py -i examples/1.fasta -o dataset.csv -l lncRNA -t NAC -seq 1
# Out:
# ###################################################################################
# ################### Feature Extraction: Several Techniques ########################
# ##########               Author: Robson Parmezan Bonidia                ###########
# ###################################################################################
#
#
# Recorded Sequence: AT1G08287|at1g08287|mirBase
# Recorded Sequence: AT1G08783|at1g08783|mirBase
# Recorded Sequence: AT1G08597|at1g08597|mirBase
# Recorded Sequence: AT1G07357|at1g07357|mirBase
# Recorded Sequence: AT1G01046|at1g01046|mirBase
# Recorded Sequence: AT1G09213|at1g09213|mirBase
# Recorded Sequence: AT1G07137|at1g07137|mirBase
# Recorded Sequence: AT1G04393|at1g04393|mirBase
# Recorded Sequence: AT1G07051|at1g07051|mirBase
# Recorded Sequence: AT1G06523|at1g06523|mirBase
# Recorded Sequence: AT1G53687|at1g53687|mirBase
# Recorded Sequence: AT1G32713|at1g32713|mirBase
# Recorded Sequence: AT1G31173|at1g31173|mirBase
# ...

# %%
import pandas as pd

df = pd.read_csv("dataset.csv")
df
# Out:
#                           nameseq         A         C         G         T  \
# 0     AT1G08287|at1g08287|mirBase  0.330952  0.180952  0.159524  0.328571
# 1     AT1G08783|at1g08783|mirBase  0.320000  0.178182  0.178182  0.323636
# 2     AT1G08597|at1g08597|mirBase  0.325893  0.205357  0.209821  0.258929
# 3     AT1G07357|at1g07357|mirBase  0.364486  0.149533  0.149533  0.336449
# 4     AT1G01046|at1g01046|mirBase  0.265700  0.178744  0.198068  0.357488
# ...                           ...       ...       ...       ...       ...
# 2535        AT3G08155|AT3G08155.1  0.302128  0.165957  0.246809  0.285106
# 2536        AT4G09025|AT4G09025.1  0.294776  0.179104  0.167910  0.358209
# 2537        AT3G09365|AT3G09365.1  0.327273  0.171717  0.210101  0.290909
# 2538        AT5G04685|AT5G04685.1  0.341743  0.199541  0.236239  0.222477
# 2539        AT5G10965|AT5G10965.5  0.283912  0.192429  0.214511  0.309148
#
#        label
# 0     lncRNA
# 1     lncRNA
# 2     lncRNA
# 3     lncRNA
# ...

# %%
# !python methods/ComplexNetworksClass-v2.py -i examples/1.fasta -o sequences.csv -l lncRNA -k 2
# Out:
# ###################################################################################
# ###################### Feature Extraction: Complex Network ########################
# ############    Arguments: -i input -o output -l label -k pattern    ##############
# ##########               Author: Robson Parmezan Bonidia                ###########
# ###################################################################################
#
#
# Recorded Sequence!!!
# Recorded Sequence!!!
# Recorded Sequence!!!
# Recorded Sequence!!!
# Recorded Sequence!!!
# Recorded Sequence!!!
# Recorded Sequence!!!
# Recorded Sequence!!!
# Recorded Sequence!!!
# Recorded Sequence!!!
# Recorded Sequence!!!
# Recorded Sequence!!!
# Recorded Sequence!!!
# Recorded Sequence!!!
# Recorded Sequence!!!
# Recorded Sequence!!!
# Recorded Sequence!!!
# Recorded Sequence!!!
# Recorded Sequence!!!
# Recorded Sequence!!!
# Recorded Sequence!!!
# Recorded Sequence!!!
# Recorded Sequence!!!
# Recorded Sequence!!!
# ...

# %%
import pandas as pd

df = pd.read_csv("sequences.csv")
df
# Out:
#                           nameseq  avg_betweenness.1-mer  avg_degree.1-mer  \
# 0     AT1G08287|at1g08287|mirBase                    0.0             209.5
# 1     AT1G08783|at1g08783|mirBase                    0.0             137.0
# 2     AT1G08597|at1g08597|mirBase                    0.0             223.5
# 3     AT1G07357|at1g07357|mirBase                    0.0             106.5
# 4     AT1G01046|at1g01046|mirBase                    0.0             103.0
# ...                           ...                    ...               ...
# 2535        AT3G08155|AT3G08155.1                    0.0             117.0
# 2536        AT4G09025|AT4G09025.1                    0.0             133.5
# 2537        AT3G09365|AT3G09365.1                    0.0             247.0
# 2538        AT5G04685|AT5G04685.1                    0.0             217.5
# 2539        AT5G10965|AT5G10965.5                    0.0            1109.0
#
# ...
